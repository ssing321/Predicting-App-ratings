# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import csv
student_data = pd.read_csv(r"C:\Users\MSI-GL63-8RD\Desktop\Elsa Hill\.ipynb_checkpoints\aks.csv")

# %%
print(student_data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import numpy as np
student_data.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating             1474
# Reviews               0
# Size                  0
# Installs              0
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# Unnamed: 13       10841
# Unnamed: 14       10841
# Unnamed: 15       10841
# Unnamed: 16       10840
# dtype: int64

# %%
student_data=student_data.drop(['Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16'], axis = 1)

# %%
x = student_data[student_data["Size"].str.contains("M|k")]
z = x['Size'].str.split('([A-Za-z]+)', expand=True)
z.rename(columns={0:'x', 1:'y',2:'k'}, inplace=True)
z.x = pd.to_numeric(z.x)
z = z.assign(new = np.where(z.y=='M',z.x*1000,z.x))
student_data.Size = z.new
student_data.Size =student_data.Size.fillna(student_data.Size.median())

# %%
student_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data=student_data.dropna(axis=0,how="any")

# %%
import pandas as pd
student_data.Installs=student_data.Installs.str.replace("+","")
student_data.Installs=student_data.Installs.str.replace(",","")
student_data.Installs=pd.to_numeric(student_data.Installs)
# Out:
# C:\Users\MSI-GL63-8RD\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
student_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
student_data.Reviews=pd.to_numeric(student_data.Reviews)
# Out:
# C:\Users\MSI-GL63-8RD\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
student_data.Reviews
# Out:
# 0        1000000
# 1            967
# 2          87510
# 3         215644
# 4            967
#           ...
# 10834          7
# 10836         38
# 10837          4
# 10839        114
# 10840     398307
# Name: Reviews, Length: 9360, dtype: int64

# %%
student_data.Price = student_data.Price.str.replace('$','')
student_data.Price = pd.to_numeric(student_data.Price)

# %%
student_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data=student_data.loc[(student_data.Rating>1)&(student_data.Rating<5)]

# %%
student_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data=student_data.loc[(student_data.Installs>student_data.Reviews)]

# %%
student_data
# Out:
#                                                      App             Category  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data = student_data.reset_index(drop =True)

# %%
student_data
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9061                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9062                                      FR Calculator               FAMILY
# 9063                                   Sya9a Maroc - FR               FAMILY
# 9064                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9065      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data.loc[((student_data.Type=='Free')&(
student_data.Price>0.0))]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
student_data
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9061                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9062                                      FR Calculator               FAMILY
# 9063                                   Sya9a Maroc - FR               FAMILY
# 9064                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9065      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data = student_data.reset_index(drop =True)

# %%
student_data
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9061                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9062                                      FR Calculator               FAMILY
# 9063                                   Sya9a Maroc - FR               FAMILY
# 9064                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9065      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.boxplot(student_data.Price)
plt.show()

# %%
plt.boxplot(student_data.Reviews)
plt.show()

# %%
plt.hist(student_data.Rating, bins = 20)
plt.show()

# %%
plt.hist(student_data.Size, bins = 10)
plt.show()

# %%
student_data=student_data.loc[(student_data.Price<200)]

# %%
plt.boxplot(student_data.Price)
plt.show()

# %%
student_data=student_data.loc[(student_data.Price<50)]

# %%
plt.boxplot(student_data.Price)
plt.show()

# %%
s1=[.25,.5,.75,.90,.94,.95,.99,1]
student_data.Price.quantile(s1)
# Out:
# 0.25     0.00
# 0.50     0.00
# 0.75     0.00
# 0.90     0.00
# 0.94     0.99
# 0.95     1.99
# 0.99     6.99
# 1.00    39.99
# Name: Price, dtype: float64

# %%
student_data.reset_index(drop=True)
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9044                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9045                                      FR Calculator               FAMILY
# 9046                                   Sya9a Maroc - FR               FAMILY
# 9047                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9048      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
student_data=student_data.loc[(student_data.Reviews<200000)]

# %%
student_data.reset_index(drop=True)
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                            Paper flowers instructions       ART_AND_DESIGN
# 4               Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7398                                           FR Tides              WEATHER
# 7399                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 7400                                      FR Calculator               FAMILY
# 7401                                   Sya9a Maroc - FR               FAMILY
# 7402                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
plt.boxplot(student_data.Installs)
plt.show()

# %%
s2 = [.1,.25,.5,.7,.9,.95,.99]
student_data.Installs.quantile(s2)
# Out:
# 0.10        1000.0
# 0.25       10000.0
# 0.50      100000.0
# 0.70     1000000.0
# 0.90     5000000.0
# 0.95    10000000.0
# 0.99    10000000.0
# Name: Installs, dtype: float64

# %%
q1=student_data.Installs.quantile(0.25)
q3=student_data.Installs.quantile(0.75)
IQR=q3-q1

# %%
UQ=q3+1.5*IQR
UQ
# Out:
# 2485000.0

# %%
student_data=student_data.loc[(student_data.Installs < 12485000.0)]

# %%
student_data
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# 5               Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9060                                           FR Tides              WEATHER
# 9061                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9062                                      FR Calculator               FAMILY
# 9063                                   Sya9a Maroc - FR               FAMILY
# 9064                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
student_data=student_data.reset_index(drop=True)

# %%
student_data
# Out:
#                                                     App             Category  \
# 0                                   Coloring book moana       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                            Paper flowers instructions       ART_AND_DESIGN
# 4               Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7370                                           FR Tides              WEATHER
# 7371                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 7372                                      FR Calculator               FAMILY
# 7373                                   Sya9a Maroc - FR               FAMILY
# 7374                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
y = student_data.Price
plt.scatter(x=student_data.Rating,y=y,marker =
"o",c="orange",edgecolor = "black" ,alpha = .6)
plt.xlabel("Rating")
plt.ylabel("Price")
plt.title("Scatter Between Price & Rating")
plt.show()

# %%
plt.scatter(x=student_data.Rating,y=student_data.Price,marker="o",c="red",edgecolor="black",alpha=1.0)
plt.xlabel("Rating")
plt.ylabel("Price")
plt.title("Relationship")
plt.show()

# %%
y = student_data.Rating
plt.scatter(x=student_data.Size,y=y,marker =
"o",c="orange",edgecolor = "black" ,alpha = .6)
plt.xlabel("Size")
plt.ylabel("Rating")
plt.title("Scatter Between Rating & Size")
plt.show()

# %%
y = student_data.Reviews
plt.scatter(x=student_data.Rating,y=y,marker =
"o",c="orange",edgecolor = "black" ,alpha = .6)
plt.xlabel("Rating")
plt.ylabel("Reviews")
plt.title("Scatter Between Rating & Reviews")
plt.show()

# %%
sns.boxplot(x = "Content Rating",y="Rating",data =student_data,palette="Set3")
plt.show()

# %%
sns.boxplot(x = "Rating",y="Category",data =student_data,palette="Set2")
plt.show()

# %%
inp1 = student_data

# %%
sns.distplot(inp1.Reviews)

# %%
inp1.Reviews = np.log1p(inp1.Reviews)
sns.distplot(inp1.Reviews)

# %%
sns.distplot(inp1.Installs)

# %%
inp1.Installs = np.log1p(inp1.Installs)
sns.distplot(inp1.Installs)

# %%
inp1=inp1.drop(['App','Last Updated','Current Ver','Android Ver'],axis=1)

# %%
inp1
# Out:
#                  Category  Rating    Reviews     Size   Installs  Type  Price  \
# 0          ART_AND_DESIGN     3.9   6.875232  14000.0  13.122365  Free    0.0
# 1          ART_AND_DESIGN     4.7  11.379520   8700.0  15.424949  Free    0.0
# 2          ART_AND_DESIGN     4.3   6.875232   2800.0  11.512935  Free    0.0
# 3          ART_AND_DESIGN     4.4   5.123964   5600.0  10.819798  Free    0.0
# 4          ART_AND_DESIGN     3.8   5.187386  19000.0  10.819798  Free    0.0
# ...                   ...     ...        ...      ...        ...   ...    ...
# 7370              WEATHER     3.8   7.086738    582.0  11.512935  Free    0.0
# 7371  BOOKS_AND_REFERENCE     4.8   3.806662    619.0   6.908755  Free    0.0
# 7372               FAMILY     4.0   2.079442   2600.0   6.216606  Free    0.0
# 7373               FAMILY     4.5   3.663562  53000.0   8.517393  Free    0.0
# 7374  BOOKS_AND_REFERENCE     4.5   4.744932  13000.0   6.908755  Free    0.0
#
# ...

# %%
inp2 = inp1.loc[:,["Type","Category","Content Rating","Genres"]]
inp2 = pd.get_dummies(inp2,drop_first=True)
inp2
# Out:
#       Type_Paid  Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 0             0                           0                0
# 1             0                           0                0
# 2             0                           0                0
# 3             0                           0                0
# 4             0                           0                0
# ...         ...                         ...              ...
# 7370          0                           0                0
# 7371          0                           0                0
# 7372          0                           0                0
# 7373          0                           0                0
# 7374          0                           0                0
#
#       Category_BOOKS_AND_REFERENCE  Category_BUSINESS  Category_COMICS  \
# 0                                0                  0                0
# 1                                0                  0                0
# ...

# %%
inp1= inp1.drop(['Type','Category','Content Rating','Genres'], axis=1)

# %%
inp1
# Out:
#       Rating    Reviews     Size   Installs  Price
# 0        3.9   6.875232  14000.0  13.122365    0.0
# 1        4.7  11.379520   8700.0  15.424949    0.0
# 2        4.3   6.875232   2800.0  11.512935    0.0
# 3        4.4   5.123964   5600.0  10.819798    0.0
# 4        3.8   5.187386  19000.0  10.819798    0.0
# ...      ...        ...      ...        ...    ...
# 7370     3.8   7.086738    582.0  11.512935    0.0
# 7371     4.8   3.806662    619.0   6.908755    0.0
# 7372     4.0   2.079442   2600.0   6.216606    0.0
# 7373     4.5   3.663562  53000.0   8.517393    0.0
# 7374     4.5   4.744932  13000.0   6.908755    0.0
#
# [7375 rows x 5 columns]

# %%
p = inp1.Rating
inp1 = inp1.drop(columns = ["Rating"],axis = 1)
pre = pd.concat([inp1,inp2],axis=1)

# %%
pre.columns= [col.strip().replace('+', '_') for col in pre.columns]
pre.columns= [col.strip().replace(';', '_') for col in pre.columns]
pre.columns= [col.strip().replace('&', '_') for col in pre.columns]
pre.columns = pre.columns.str.replace(' ', '')
f1 = "+".join(pre.columns.to_list())

# %%
f1
# Out:
# 'Reviews+Size+Installs+Price+Type_Paid+Category_AUTO_AND_VEHICLES+Category_BEAUTY+Category_BOOKS_AND_REFERENCE+Category_BUSINESS+Category_COMICS+Category_COMMUNICATION+Category_DATING+Category_EDUCATION+Category_ENTERTAINMENT+Category_EVENTS+Category_FAMILY+Category_FINANCE+Category_FOOD_AND_DRINK+Category_GAME+Category_HEALTH_AND_FITNESS+Category_HOUSE_AND_HOME+Category_LIBRARIES_AND_DEMO+Category_LIFESTYLE+Category_MAPS_AND_NAVIGATION+Category_MEDICAL+Category_NEWS_AND_MAGAZINES+Category_PARENTING+Category_PERSONALIZATION+Category_PHOTOGRAPHY+Category_PRODUCTIVITY+Category_SHOPPING+Category_SOCIAL+Category_SPORTS+Category_TOOLS+Category_TRAVEL_AND_LOCAL+Category_VIDEO_PLAYERS+Category_WEATHER+ContentRating_Everyone+ContentRating_Everyone10_+ContentRating_Mature17_+ContentRating_Teen+ContentRating_Unrated+Genres_Action_Action_Adventure+Genres_Adventure+Genres_Adventure_Action_Adventure+Genres_Adventure_BrainGames+Genres_Arcade+Genres_Arcade_Action_Adventure+Genres_Arcade_PretendPlay
# ...

# %%
pre['Rating'] = p

# %%
pre = pre.reset_index(drop = True)

# %%
sns.distplot(pre.Rating)
plt.show()

# %%
df_train,df_test = train_test_split(pre,test_size = 0.3,random_state = 1234)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metric
import statsmodels.formula.api as sm

# %%
df_train,df_test = train_test_split(pre,test_size = 0.3,random_state = 1234)

# %%
df_test
# Out:
#         Reviews     Size   Installs  Price  Type_Paid  \
# 1537   8.130648   9500.0  10.819798   3.99          1
# 38    12.069863  24000.0  16.118096   0.00          0
# 4885   2.484907   2200.0   6.908755   0.00          0
# 1129   6.198479  15000.0  11.512935   0.00          0
# 4193   4.369448   2800.0   8.517393   0.00          0
# ...         ...      ...        ...    ...        ...
# 3334  10.293534   4300.0  13.815512   0.00          0
# 6615   2.484907  20000.0   6.216606   1.99          1
# 1456  10.427802  16000.0  15.424949   0.00          0
# 4821  10.636480   5400.0  13.815512   0.00          0
# 5621   3.526361  44000.0   6.908755   0.00          0
#
#       Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 1537                           0                0
# 38                             0                0
# 4885                           0                0
# 1129                           0                0
# 4193                           0                0
# ...

# %%
df_train
# Out:
#         Reviews     Size   Installs  Price  Type_Paid  \
# 1481  10.856997  22000.0  16.118096   0.00          0
# 6420   3.912023   7100.0   8.517393   0.00          0
# 2016  10.417508   3900.0  15.424949   0.00          0
# 4387   3.433987  99000.0   8.517393   0.00          0
# 6319   5.017280  11000.0   8.517393   0.00          0
# ...         ...      ...        ...    ...        ...
# 3276   8.492696  27000.0  11.512935   0.00          0
# 7221   6.487684  22000.0   8.517393   0.99          1
# 1318  12.019074  91000.0  15.424949   0.00          0
# 723   10.043163  13000.0  13.815512   0.00          0
# 2863   4.682131   1200.0  10.819798   0.00          0
#
#       Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 1481                           0                0
# 6420                           0                0
# 2016                           0                0
# 4387                           0                0
# 6319                           0                0
# ...

# %%
X_train, y_train = train_test_split(df_train,test_size = 0.3)
X_test, y_test = train_test_split(df_test,test_size = 0.3)

# %%
formula = "Rating~"+ f1

# %%
import statsmodels.formula.api as sm
model = sm.ols(formula=formula, data=df_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     8.774
# Date:                Tue, 30 Jun 2020   Prob (F-statistic):          1.33e-128
# Time:                        21:28:29   Log-Likelihood:                -3493.7
# No. Observations:                5162   AIC:                             7221.
# Df Residuals:                    5045   BIC:                             7988.
# Df Model:                         116
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
pred_Rating1 = model.predict(df_test)
pred_Rating1
# Out:
# 1537    4.307190
# 38      4.657731
# 4885    3.857383
# 1129    3.920542
# 4193    3.952607
#           ...
# 3334    4.459525
# 6615    4.047889
# 1456    3.900971
# 4821    4.350673
# 5621    4.009006
# Length: 2213, dtype: float64
